# %%
import pandas as pd
import os

os.chdir('/Users/ori.fogler/PycharmProjects/quick-and-safe')

import random
import time
from tqdm import tqdm
from geometry.coord import Coord
from geometry.circle import Circle
from geometry.polygon import Polygon
import matplotlib.pyplot as plt
from algorithms.multiple_threats import multiple_threats_shortest_path_with_budget_constraint_given_order_and_budgets
from algorithms.layers import rrg_layers_multiple_threats_shortest_path_with_budget_constraint
from algorithms.layers import exaustive_layers_multiple_threats_shortest_path_with_budget_constraint
from algorithms.genetic import genetic_multiple_threats_shortest_path_with_budget_constraint

os.chdir('/Users/ori.fogler/PycharmProjects/quick-and-safe/experiments')

# %%
random.seed(29)

x_lim = 1000
y_lim = 500
num_circles = 6 + 1

source = Coord(50, 250)
target = Coord(950, 250)

split_lines = list(range(55, 950, int(x_lim / num_circles)))

obstacles_idx = [2, 4]
circles = []
circles_obstacles = []
for i, split1, split2 in zip(range(len(split_lines)), split_lines[:-1], split_lines[1:]):
    c_x  = (split1 + split2) / 2
    c_y = 250 + random.randint(-100, 100)
    c_r = random.randint(50, int(0.9 * min([c_x - split1, split2 - c_x, y_lim - c_y, c_y])))
    circle = Circle(center=Coord(c_x, c_y), radius=c_r)
    if not i in obstacles_idx:
        circles.append(circle)
    circles_obstacles.append(circle)

budget = 400

sum_of_radii = sum([c.radius for c in circles])
alphas = [c.radius / sum_of_radii for c in circles_obstacles]
path, length, risk = multiple_threats_shortest_path_with_budget_constraint_given_order_and_budgets(
    source, target, circles_obstacles, budget=budget, alphas=alphas, obstacles_idx=obstacles_idx)

plt.gca().set_aspect('equal', adjustable='box')
source.plot()
target.plot()
for i, co in enumerate(circles_obstacles):
    if i in obstacles_idx:
        co.plot(color='blue')
    else:
        co.plot()

path.plot()
plt.show()
# Out:
# running analytical algorithm

# %%
x_lim = 1000
y_lim = 500
num_circles = 6 + 1

source = Coord(50, 250)
target = Coord(950, 250)

f = open('few_obstacles.csv', "a")

for i in range(3):
    print(f'running for seed {i}')
    random.seed(i)

    split_lines = list(range(55, 950, int(x_lim / num_circles)))

    obstacles_idx = [2, 4]
    circles = []
    circles_obstacles = []
    for i, split1, split2 in zip(range(len(split_lines)), split_lines[:-1], split_lines[1:]):
        c_x  = (split1 + split2) / 2
        c_y = 250 + random.randint(-100, 100)
        c_r = random.randint(50, int(0.9 * min([c_x - split1, split2 - c_x, y_lim - c_y, c_y])))
        circle = Circle(center=Coord(c_x, c_y), radius=c_r)
        if not i in obstacles_idx:
            circles.append(circle)
        circles_obstacles.append(circle)

    # for budget in [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]:
    for budget in [100]:
        # *** partition_radius ***
        start = time.time()
        sum_of_radii = sum([c.radius for c in circles])
        alphas = [c.radius / sum_of_radii for c in circles_obstacles]
        path, length, risk = multiple_threats_shortest_path_with_budget_constraint_given_order_and_budgets(
            source, target, circles, budget=budget, alphas=alphas, obstacles_idx=obstacles_idx)
        elapsed = time.time() - start
        f.write(f'partition_radius,{i},{len(circles)},{budget},{length},{risk},{elapsed},{time.time()}' + '\n')

        # *** partition_st ***
        start = time.time()
        sum_of_dists = sum([abs(c.center.y - source.y) for c in circles])
        alphas = [abs(c.center.y - source.y) / sum_of_dists for c in circles_obstacles]
        path, length, risk = multiple_threats_shortest_path_with_budget_constraint_given_order_and_budgets(
            source, target, circles, budget, alphas=alphas, obstacles_idx=obstacles_idx)
        elapsed = time.time() - start
        f.write(f'partition_st,{i},{len(circles)},{budget},{length},{risk},{elapsed},{time.time()}' + '\n')

        try:
            # *** exhaustive ***
            start = time.time()
            sum_of_dists = sum([abs(c.center.y - source.y) for c in circles])
            alphas = [abs(c.center.y - source.y) / sum_of_dists for c in circles]
            path, length, risk = exaustive_layers_multiple_threats_shortest_path_with_budget_constraint(
                source, target, circles, budget, obstacles_idx=obstacles_idx)
            elapsed = time.time() - start
            f.write(f'exhaustive,{i},{len(circles)},{budget},{length},{risk},{elapsed},{time.time()}' + '\n')
        except:
            print(f'failed to do exhaustive with seed {i}')

        # *** solver ***
        start = time.time()
        path, length, risk = rrg_layers_multiple_threats_shortest_path_with_budget_constraint(
            source, target, circles, budget=budget, obstacles_idx=obstacles_idx)
        elapsed = time.time() - start
        f.write(f'solver,{i},{len(circles)},{budget},{length},{risk},{elapsed},{time.time()}' + '\n')

f.close()
# Out:
# running for seed 0
# running analytical algorithm
# running analytical algorithm
# failed to do exhaustive with seed 5
# running layers algorithm
# 100%|███████████████████████████████████████| 2000/2000 [00:22<00:00, 87.72it/s]
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 294.68it/s]
# running for seed 1
# running analytical algorithm
# running analytical algorithm
# failed to do exhaustive with seed 5
# running layers algorithm
# 100%|███████████████████████████████████████| 2000/2000 [00:22<00:00, 87.44it/s]
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 302.96it/s]
# running for seed 2
# running analytical algorithm
# running analytical algorithm
# failed to do exhaustive with seed 5
# running layers algorithm
# 100%|███████████████████████████████████████| 2000/2000 [00:23<00:00, 86.72it/s]
# 100%|██████████████████████████████████████████| 10/10 [00:00<00:00, 290.84it/s]

# %%
data = pd.read_csv('no_obstacles.csv', header=0, index_col=False)

# %%
data
# Out:
#                method  seed  num_circles  budget      length        risk  \
# 0    partition_radius     0            6       0  944.686082    0.000000
# 1        partition_st     0            6       0  944.686082    0.000000
# 2          exhaustive     0            6       0  972.023539  200.618565
# 3    partition_radius     0            6     100  939.868179  100.000000
# 4        partition_st     0            6     100  939.060827  100.000000
# ..                ...   ...          ...     ...         ...         ...
# 204            solver     3            6     600  901.517782  436.586192
# 205            solver     3            6     700  901.517782  436.586192
# 206            solver     3            6     800  901.517782  436.586192
# 207            solver     3            6     900  901.517782  436.586192
# 208            solver     3            6    1000  901.517782  436.586192
#
#          elapsed            ts
# 0       0.876043  1.695851e+09
# 1       0.768294  1.695851e+09
# 2       6.871084  1.695851e+09
# 3       0.752304  1.695851e+09
# 4       0.844469  1.695851e+09
# ..           ...           ...
# 204  1993.982801  1.695880e+09
# 205  5500.176918  1.695886e+09
# 206    78.750180  1.695886e+09
# 207   212.625003  1.695886e+09
# 208   330.227100  1.695886e+09
#
# [209 rows x 8 columns]

# %%
mean_data = data.groupby(['method', 'num_circles', 'budget']).mean().reset_index()
# methods = list(set(mean_data['method']))
methods = ['solver', 'partition_radius', 'partition_st', 'exhaustive']
budgets = sorted(list(set(mean_data['budget'])))
linestyles = ['--','-.',':','--']

# %%
cur_df = mean_data.loc[mean_data['method'] == 'exhaustive']
cur_df['length']
# Out:
# 0      946.923022
# 1     1009.156796
# 2      937.624491
# 3      916.999675
# 4      909.574780
# 5      903.954764
# 6      901.799804
# 7      900.961500
# 8      900.521746
# 9      900.521746
# 10     900.521746
# Name: length, dtype: float64

# %%
plt.figure(figsize=(6, 12))
plt.subplot(3, 1, 1)
for i, method in enumerate(methods):
    cur_df = mean_data.loc[mean_data['method'] == method]
    plt.plot(cur_df['budget'], cur_df['length'], linestyle=linestyles[i], linewidth=2)
plt.legend(methods)
plt.grid(True)
plt.xlabel('budget')
plt.ylabel('path length')

plt.subplot(3, 1, 2)
for i, method in enumerate(methods):
    cur_df = mean_data.loc[mean_data['method'] == method]
    plt.plot(cur_df['budget'], cur_df['risk'], linestyle=linestyles[i], linewidth=2)
plt.legend(methods)
plt.grid(True)
plt.xlabel('budget')
plt.ylabel('path risk')

plt.subplot(3, 1, 3)
for i, method in enumerate(methods):
    cur_df = mean_data.loc[mean_data['method'] == method]
    plt.plot(cur_df['budget'], cur_df['elapsed'], linestyle=linestyles[i], linewidth=2)
plt.legend(methods)
plt.grid(True)
plt.xlabel('budget')
plt.ylabel('computation time')
# Out:
# Text(0, 0.5, 'computation time')
